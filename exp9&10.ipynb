# %% [markdown]
# <a href="https://colab.research.google.com/github/Nada-Naveesh/Deep_Learning/blob/main/exp9%2610.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)
max_len = 500
x_train = pad_sequences(x_train, padding='post', maxlen=max_len)
x_test = pad_sequences(x_test, padding='post', maxlen=max_len)
model = Sequential()
model.add(Embedding(input_dim=10000, output_dim=100, input_length=max_len))
model.add(LSTM(64, return_sequences=True))
model.add(GlobalAveragePooling1D())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5, batch_size=64, validation_data=(x_test, y_test), verbose=2)
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
embedding_weights = model.layers[0].get_weights()[0]
print("First 5 rows of word embeddings:")
print(embedding_weights[:5])
# Out:
# Epoch 1/5
# 391/391 - 268s - 686ms/step - accuracy: 0.7231 - loss: 0.5325 - val_accuracy: 0.8315 - val_loss: 0.4083
# Epoch 2/5
# 391/391 - 323s - 825ms/step - accuracy: 0.8928 - loss: 0.2829 - val_accuracy: 0.8861 - val_loss: 0.2818
# Epoch 3/5
# 391/391 - 321s - 822ms/step - accuracy: 0.9298 - loss: 0.1953 - val_accuracy: 0.8816 - val_loss: 0.3067
# Epoch 4/5
# 391/391 - 266s - 680ms/step - accuracy: 0.9484 - loss: 0.1496 - val_accuracy: 0.8746 - val_loss: 0.3096
# Epoch 5/5
# 391/391 - 320s - 820ms/step - accuracy: 0.9634 - loss: 0.1128 - val_accuracy: 0.8804 - val_loss: 0.3480
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.8809 - loss: 0.3497
# Test Accuracy: 0.8804
# First 5 rows of word embeddings:
# [[ 2.50399560e-02  2.71894753e-01  8.25949252e-01 -6.47386014e-02
#    9.28015471e-01  5.86597398e-02 -3.88947204e-02  5.26470661e-01
#   -2.42625087e-01  3.13883275e-01 -4.26684558e-01 -3.27371731e-02
#   -1.43457741e-01 -1.09375966e+00 -8.32111463e-02 -1.56061739e-01
# ...
